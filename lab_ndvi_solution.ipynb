# %%
import numpy as np
import rasterio
import matplotlib.pyplot as plt


ds = rasterio.open('stacked.tif')
bands = ds.read().astype('float32')

red, nir = bands
nvdi = (nir-red)/(nir+red)

plt.imshow(nvdi, cmap='RdYlGn')
plt.show()
